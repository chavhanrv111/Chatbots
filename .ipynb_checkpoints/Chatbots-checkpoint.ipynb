# %% [markdown]
# # Chatbot using NLP and Neural Networks in Python

# %%
#tag means classes
# patterns means what user is going to ask
# response is chatbot response

data={"intents":[
    {"tag":"greeting",
     "patterns":["Hello","How are you?","Hi there","Hi","What's up"],
     "responses":["Howdy Partner!","Hello","How are you doing?","Greetings!","How do you do?"]
    },
     {"tag":"age",
     "patterns":["how old are you","when is your birthday","when was you born"],
     "responses":["I am 24 years old","I was born in 1996","My birthday is July 3rd and I was born in 1996","03/07/1996"]
    },
      {"tag":"date",
     "patterns":["what are you doing this weekend?",
                 "do you want to hangout sometime?","what are your plans for this week"],
     "responses":["I am available all week","I don't have any plans","I am not busy"]
    },   
     {"tag":"name",
     "patterns":["what's your name","what are you called","who are you"],
     "responses":["My name is Kippi","I'm Kippi","Kippi"]
    },
     {"tag":"goodbye",
     "patterns":["bye","g2g","see ya","adios","cya"],
     "responses":["It was nice speaking to you","See you later","Speak soon"]
    }
]}

# %%
# For each tag we created, we would specify patterns. Essentially, this defines the different ways of how a user may
# pose a query to the chatbot.

# The chatbot would then take these patterns and use them as training data to determine what someone
# asking for chatbot name would like so that it could adopt to different ways someone may ask to know the bot's name.

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.6 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\sumit\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk) (1.1.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp310-cp310-win_amd64.whl (267 kB)
#      -------------------------------------- 267.7/267.7 kB 1.5 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\sumit\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click->nltk) (0.4.5)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.7 regex-2022.10.31 tqdm-4.64.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: C:\Users\SUMIT\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#   WARNING: The script tqdm.exe is installed in 'C:\Users\SUMIT\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'C:\Users\SUMIT\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SUMIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SUMIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\SUMIT\AppData\Roaming\nltk_data...
# True

# %%
# In order to create our training data below steps to be followed:

# create a vocabulary of all the words used in the patterns
# create a list of the classes- tags of each intent
# create a list of all the patterns within the intents file
# create a list of all the associated tags to go with each patterns in the intents file

# %%
# initializing lemmatizer to get stem of words

lemmatizer= WordNetLemmatizer()

words=[]
classes=[]
doc_x=[]
doc_y=[]

# %%
# loop through all the intents
# tokenize each pattern and append token to words, the patterns and the
# associated tag to their associated list

# %%
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens=nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_x.append(pattern)
        doc_y.append(intent["tag"])
    #add tag to the classes
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# %%
# lemmatize all the words in the vocab and convert them to lowercase

words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

# %%
# sorting the vocab and classes in alphavetical order and taking the set to ensure no duplicates occur

words=sorted(set(words))
classes=sorted(set(classes))

# %%
print(words)
# Out:
# ["'s", 'adios', 'are', 'birthday', 'born', 'bye', 'called', 'cya', 'do', 'doing', 'for', 'g2g', 'hangout', 'hello', 'hi', 'how', 'is', 'name', 'old', 'plan', 'see', 'sometime', 'there', 'this', 'to', 'up', 'wa', 'want', 'week', 'weekend', 'what', 'when', 'who', 'ya', 'you', 'your']

# %%
print(classes)
# Out:
# ['age', 'date', 'goodbye', 'greeting', 'name']

# %%
print(doc_x)
# Out:
# ['Hello', 'How are you?', 'Hi there', 'Hi', "What's up", 'how old are you', 'when is your birthday', 'when was you born', 'what are you doing this weekend?', 'do you want to hangout sometime?', 'what are your plans for this week', "what's your name", 'what are you called', 'who are you', 'bye', 'g2g', 'see ya', 'adios', 'cya']

# %%
print(doc_y)
# Out:
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'age', 'age', 'age', 'date', 'date', 'date', 'name', 'name', 'name', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye']

# %%
# list for training data
training=[]
out_empty=[0]*len(classes)

# creating bag of words model
for idx, doc in enumerate(doc_x):
    bow=[]
    text=lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    output_row= list(out_empty)
    output_row[classes.index(doc_y[idx])]=1
    
    training.append([bow, output_row])

random.shuffle(training)

training=np.array(training, dtype=object)

train_X= np.array(list(training[:,0]))
train_y=np.array(list(training[:,1]))

# %%
# The model will look at the features and predict the tag associated with the features
# then will select an appropriate message/response from the tag

# %%
input_shape= (len(train_X[0]),)
output_shape=len(train_y[0])
epochs=200

# %%
model=Sequential()
model.add(Dense(128, input_shape=input_shape,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation='softmax'))
adam=tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)

model.compile(loss='categorical_crossentropy',
             optimizer=adam,
             metrics=["accuracy"])

print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,317
# Trainable params: 13,317
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.6548 - accuracy: 0.1579
# Epoch 2/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5756 - accuracy: 0.2632
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4502 - accuracy: 0.4737
# Epoch 4/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2759 - accuracy: 0.7895
# Epoch 5/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1880 - accuracy: 0.8947
# Epoch 6/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1145 - accuracy: 0.8421
# Epoch 7/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0356 - accuracy: 0.7368
# Epoch 8/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8791 - accuracy: 0.7895
# Epoch 9/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8098 - accuracy: 0.8947
# Epoch 10/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6324 - accuracy: 0.8947
# Epoch 11/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5800 - accuracy: 0.8947
# Epoch 12/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.4141 - accuracy: 0.9474
# Epoch 13/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3942 - accuracy: 0.8947
# Epoch 14/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2045 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2255 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.9474
# Epoch 17/200
# 1/1 [==============================] - 0s 0s/step - loss: 0.1536 - accuracy: 0.9474
# Epoch 18/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1574 - accuracy: 0.9474
# Epoch 19/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1147 - accuracy: 0.9474
# Epoch 20/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1034 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1252 - accuracy: 0.8947
# Epoch 24/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0989 - accuracy: 0.9474
# Epoch 33/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0612 - accuracy: 0.9474
# Epoch 35/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1071 - accuracy: 0.9474
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0915 - accuracy: 0.9474
# Epoch 40/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0450 - accuracy: 0.9474
# Epoch 41/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.9379e-04 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.4240e-05 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0513 - accuracy: 0.9474
# Epoch 48/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0805e-04 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0774e-04 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.8139e-04 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.0460e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9509e-04 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0505 - accuracy: 0.9474
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.4531e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3120e-04 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 5ms/step - loss: 8.6783e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0653e-04 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1707e-05 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 0s/step - loss: 1.2405e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3874e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6257e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.4625e-04 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.3215e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0784 - accuracy: 0.9474
# Epoch 82/200
# 1/1 [==============================] - 0s 17ms/step - loss: 6.0793e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3389e-04 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9685e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 5ms/step - loss: 5.4542e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.7676e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5382e-04 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4852e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.8021e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1438e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.0871e-05 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1798e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6547e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0196e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4107e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4133e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1409e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.5288e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0838e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0601 - accuracy: 0.9474
# Epoch 114/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.6159e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.0684e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 0s/step - loss: 4.1193e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7601e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1578e-05 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 0s/step - loss: 9.7042e-05 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6650e-05 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 0s/step - loss: 2.5757e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.8380e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 13ms/step - loss: 8.3269e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.4474e-05 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.9942e-05 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4232e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.3643e-05 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3405e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3799e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.1417e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 0s/step - loss: 7.2908e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6353e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1954e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0730e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7080e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.1310e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.5992e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6651e-05 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 5ms/step - loss: 9.6430e-06 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0312e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4191e-05 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3144e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 0s/step - loss: 8.5076e-05 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4858e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1271e-05 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5082e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2494e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7919e-05 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3025e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6689e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.3244e-05 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 0s/step - loss: 3.9512e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0983e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 15ms/step - loss: 3.2017e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2775e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5662e-04 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1822e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.6535e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7861e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9894e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3640e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9596e-04 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.5185e-05 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7758e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2717e-06 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 5ms/step - loss: 7.5276e-05 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5880e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.8023e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 13ms/step - loss: 6.5352e-05 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 5ms/step - loss: 3.3600e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8387e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6269e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7638e-05 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1091e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.6177e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4495e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7101e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9718e-05 - accuracy: 1.0000

# %%
def clean_text(text):
    tokens=nltk.word_tokenize(text)
    tokens=[lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens=clean_text(text)
    bow=[0]*len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word==w:
                bow[idx]=1
    return np.array(bow)

# %%
def pred_class(text, vocab, labels):
    bow= bag_of_words(text, vocab)
    result= model.predict(np.array([bow]))[0]
    thresh=0.2
    y_pred=[[idx, res] for idx, res in enumerate(result) if res>thresh]
    
    y_pred.sort(key=lambda x:x[1], reverse=True)
    return_list=[]
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json):
    tag=intents_list[0]
    list_of_intents= intents_json["intents"]
    for i in list_of_intents:
        if i["tag"]==tag:
            result= random.choice(i["responses"])
            break
    return result

# %%
# running the chatbot

while True:
    message= input("")
    if message =='bye':
        break
    intents=pred_class(message, words, classes)
    result=get_response(intents,data)
    print(result)
# Out:
# hello
# Howdy Partner!
# hii
# Speak soon
# bye
